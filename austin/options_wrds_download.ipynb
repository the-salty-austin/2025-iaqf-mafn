# %%
import os
import sys
from dotenv import load_dotenv

notebook_path = os.getcwd()

# One level up from the notebook
PROJECT_ROOT = os.path.abspath(os.path.join(notebook_path, "../"))

DATA_ROOT = os.path.join(PROJECT_ROOT, "data")

sys.path.insert(1, PROJECT_ROOT)
load_dotenv()
# Out:
# True

# %%
import wrds
import pandas as pd
import numpy as np

# %% [markdown]
# `wrds_username` is your own WRDS username (the same as your login to the WRDS website). You will be prompted once for your WRDS username and password on your first login, at the Connection() step, but then, after running create_pgpass_file() once, you should be able to connect from then on without needing to do so. Test this by disconnecting and reconnecting, using the following:

# %%
conn = wrds.Connection(wrds_username='austinshih90')
conn.create_pgpass_file() #Austin123456
# Out:
# Loading library list...
# Done

# %% [markdown]
# https://wrds-www.wharton.upenn.edu/documents/1443/wrds_connection.html

# %%
conn.list_libraries()
# Out:
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'bank_premium_samp',
#  'banksamp',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_eur',
#  'boardex_na',
#  'boardex_row',
#  'boardex_trial',
#  'boardex_uk',
#  'boardsmp',
#  'bvd',
#  'bvd_ama_large',
#  'bvd_ama_medium',
#  'bvd_ama_small',
#  'bvd_ama_verylarge',
#  'bvd_amadeus_trial',
#  'bvd_bvdbankf',
#  'bvd_bvdbankf_trial',
#  'bvd_orbis_large',
#  'bvd_orbis_medium',
#  'bvd_orbis_small',
#  'bvd_orbis_trial',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'cboe_sample',
#  'cboesamp',
#  'ciq',
#  'ciq_common',
#  'ciq_keydev',
#  'ciq_ratings',
#  'ciq_transcripts',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
#  'ciqsamp_transactions',
#  'ciqsamp_transcripts',
#  'cisdmsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_filings',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'comp_snapshot',
#  'compa',
#  'compb',
#  'compg',
#  'compm',
#  'compsamp',
#  'compsamp_all',
#  'compsamp_snapshot',
#  'compseg',
#  'compsnap',
#  'contrib',
#  'contrib_as_filed_financials',
#  'contrib_ceo_turnover',
#  'contrib_char_returns',
#  'contrib_corporate_culture',
#  'contrib_general',
#  'contrib_global_factor',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_a_treasuries',
#  'crsp_q_ccm',
#  'crsp_q_indexes',
#  'crsp_q_indexhist',
#  'crsp_q_mutualfunds',
#  'crsp_q_stock',
#  'crsp_q_treasuries',
#  'crspq',
#  'crspsamp',
#  'crspsamp_all',
#  'crspsamp_mf',
#  'csmsamp_all',
#  'dealscan',
#  'djones',
#  'djones_all',
#  'dmef',
#  'dmef_all',
#  'doe',
#  'doe_all',
#  'etfg_samp',
#  'etfgsamp',
#  'eventus',
#  'evts_all',
#  'execcomp',
#  'factsamp_all',
#  'factsamp_revere',
#  'ff',
#  'ff_all',
#  'fisd',
#  'fisd_common',
#  'fisd_fisd',
#  'fisd_naic',
#  'fisdsamp',
#  'fisdsamp_all',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'frb_all',
#  'fssamp',
#  'ftsesamp',
#  'ftsesamp_russell_us',
#  'gmi',
#  'gmi_all',
#  'gutenberg',
#  'hfrsamp',
#  'hfrsamp_hfrdb',
#  'ibes',
#  'ibessamp_kpi',
#  'ifgr',
#  'ifgrsamp',
#  'ims_obp_trial',
#  'imssamp',
#  'infogroup_business_academic',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'insdsamp',
#  'iri',
#  'iri_all',
#  'iss',
#  'iss_incentive_lab',
#  'iss_incentive_lab_europe',
#  'iss_va_mf',
#  'iss_va_shareholder',
#  'iss_va_vote_us',
#  'issm',
#  'issm_nasd1987',
#  'issm_nasd1988',
#  'issm_nasd1989',
#  'issm_nasd1990',
#  'issm_nasd1991',
#  'issm_nasd1992',
#  'issm_nyam1983',
#  'issm_nyam1984',
#  'issm_nyam1985',
#  'issm_nyam1986',
#  'issm_nyam1987',
#  'issm_nyam1988',
#  'issm_nyam1989',
#  'issm_nyam1990',
#  'issm_nyam1991',
#  'issm_nyam1992',
#  'kpisamp',
#  'macrofin',
#  'macrofin_comm_trade',
#  'markit',
#  'markit_cds',
#  'markit_cdxcomps',
#  'markit_cdxconst',
#  'markit_red',
#  'mfl',
#  'mflinks_all',
#  'midas',
#  'morningstarsamp_cisdm',
#  'mrktsamp',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'mrktsamp_msf',
#  'msci_esg_samp',
#  'msciesmp',
#  'msrb',
#  'msrb_all',
#  'msrbsamp',
#  'msrbsamp_all',
#  'omtrial',
#  'optionm',
#  'optionm_all',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'otc',
#  'otc_endofday',
#  'phlx',
#  'phlx_all',
#  'pitchsmp',
#  'preqin',
#  'preqin_cashflow',
#  'preqin_deals',
#  'preqin_gp',
#  'preqin_lp',
#  'preqin_pe',
#  'preqin_vc',
#  'preqsamp',
#  'preqsamp_all',
#  'public',
#  'public_all',
#  'pwt',
#  'pwt_all',
#  'ravenpack_common',
#  'ravenpack_dj',
#  'ravenpack_trial',
#  'reprisk_sample',
#  'repsamp',
#  'revelio_samp',
#  'revsamp',
#  'risk',
#  'risk_directors',
#  'risk_governance',
#  'risk_proposals',
#  'risk_votes',
#  'risksamp',
#  'risksamp_all',
#  'rpna',
#  'rpnasamp',
#  'rq_all',
#  'rstat_samp',
#  'rstatsmp',
#  'sdcsamp',
#  'secsamp',
#  'secsamp_all',
#  'snapsamp',
#  'snlsamp',
#  'snlsamp_fig',
#  'sustainalyticssamp_all',
#  'sustsamp',
#  'taqm_2003',
#  'taqm_2004',
#  'taqm_2005',
#  'taqm_2006',
#  'taqm_2007',
#  'taqm_2008',
#  'taqm_2009',
#  'taqm_2010',
#  'taqm_2011',
#  'taqm_2012',
#  'taqm_2013',
#  'taqm_2014',
#  'taqm_2015',
#  'taqm_2016',
#  'taqm_2017',
#  'taqm_2018',
#  'taqm_2019',
#  'taqm_2020',
#  'taqm_2021',
#  'taqm_2022',
#  'taqm_2023',
#  'taqm_2024',
#  'taqm_2025',
#  'taqmsamp',
#  'taqmsamp_all',
#  'taqmsec',
#  'taqsamp',
#  'taqsamp_all',
#  'tass',
#  'tfn',
#  'totalq',
#  'totalq_all',
#  'tr_13f',
#  'tr_common',
#  'tr_dealscan',
#  'tr_ds_comds',
#  'tr_ds_econ',
#  'tr_ds_equities',
#  'tr_ds_fut',
#  'tr_ibes',
#  'tr_ibes_guidance',
#  'tr_insiders',
#  'tr_mutualfunds',
#  'tr_sdc_samples',
#  'tr_tass',
#  'tr_worldscope',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trcommon',
#  'trcstsmp',
#  'trdbdmismp',
#  'trdbwbsmp',
#  'trdssamp',
#  'trdstrm',
#  'tresgsmp',
#  'trsamp',
#  'trsamp_all',
#  'trsamp_db_dmi',
#  'trsamp_db_wb',
#  'trsamp_ds_eq',
#  'trsamp_dscom',
#  'trsamp_dsecon',
#  'trsamp_dsfut',
#  'trsamp_esg',
#  'trsamp_sdc_ma',
#  'trsamp_sdc_ni',
#  'trsamp_worldscope',
#  'trucost_samp',
#  'trws',
#  'twoiq_samp',
#  'twoiqsmp',
#  'wappsamp',
#  'wenvsmp',
#  'wmfsmp',
#  'wrds_environmental_samp',
#  'wrds_insiders',
#  'wrds_insiders_samp',
#  'wrds_lib_internal',
#  'wrds_mutualfund_samp',
#  'wrds_sec_search',
#  'wrdsapps',
#  'wrdsapps_backtest_basic',
#  'wrdsapps_backtest_plus',
#  'wrdsapps_bondret',
#  'wrdsapps_eushort',
#  'wrdsapps_evtstudy_int',
#  'wrdsapps_evtstudy_int_ginsight',
#  'wrdsapps_evtstudy_lr',
#  'wrdsapps_evtstudy_lr_ciq',
#  'wrdsapps_evtstudy_us',
#  'wrdsapps_finratio',
#  'wrdsapps_finratio_ccm',
#  'wrdsapps_finratio_ibes',
#  'wrdsapps_finratio_ibes_ccm',
#  'wrdsapps_link_comp_eushort',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_comp_bdx',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm',
#  'wrdsapps_link_datastream_wscope',
#  'wrdsapps_link_dealscan_wscope',
#  'wrdsapps_link_supplychain',
#  'wrdsapps_link_trinsider_bdx',
#  'wrdsapps_patents',
#  'wrdsapps_plink_boardex_trinsider',
#  'wrdsapps_plink_exec_boardex',
#  'wrdsapps_plink_exec_trinsider',
#  'wrdsapps_subsidiary',
#  'wrdsapps_windices',
#  'wrdsappssamp_all',
#  'wrdsinsd',
#  'wrdssec',
#  'wrdssec_all',
#  'wrdssec_bow',
#  'wrdssec_common',
#  'wrdssec_insiders',
#  'wrdssec_midas',
#  'wrdssec_secsa',
#  'zacksamp',
#  'zacksamp_all']

# %%
conn.list_tables(library='optionm_all')
# Out:
# ['borrate1996',
#  'borrate1997',
#  'borrate1998',
#  'borrate1999',
#  'borrate2000',
#  'borrate2001',
#  'borrate2002',
#  'borrate2003',
#  'borrate2004',
#  'borrate2005',
#  'borrate2006',
#  'borrate2007',
#  'borrate2008',
#  'borrate2009',
#  'borrate2010',
#  'borrate2011',
#  'borrate2012',
#  'borrate2013',
#  'borrate2014',
#  'borrate2015',
#  'borrate2016',
#  'borrate2017',
#  'borrate2018',
#  'borrate2019',
#  'borrate2020',
#  'borrate2021',
#  'borrate2022',
#  'borrate2023',
#  'distrd',
#  'distrprojd1996',
#  'distrprojd1997',
#  'distrprojd1998',
#  'distrprojd1999',
#  'distrprojd2000',
#  'distrprojd2001',
#  'distrprojd2002',
#  'distrprojd2003',
#  'distrprojd2004',
#  'distrprojd2005',
#  'distrprojd2006',
#  'distrprojd2007',
#  'distrprojd2008',
#  'distrprojd2009',
#  'distrprojd2010',
#  'distrprojd2011',
#  'distrprojd2012',
#  'distrprojd2013',
#  'distrprojd2014',
#  'distrprojd2015',
#  'distrprojd2016',
#  'distrprojd2017',
#  'distrprojd2018',
#  'distrprojd2019',
#  'distrprojd2020',
#  'distrprojd2021',
#  'distrprojd2022',
#  'distrprojd2023',
#  'exchgd',
#  'fwdprd1996',
#  'fwdprd1997',
#  'fwdprd1998',
#  'fwdprd1999',
#  'fwdprd2000',
#  'fwdprd2001',
#  'fwdprd2002',
#  'fwdprd2003',
#  'fwdprd2004',
#  'fwdprd2005',
#  'fwdprd2006',
#  'fwdprd2007',
#  'fwdprd2008',
#  'fwdprd2009',
#  'fwdprd2010',
#  'fwdprd2011',
#  'fwdprd2012',
#  'fwdprd2013',
#  'fwdprd2014',
#  'fwdprd2015',
#  'fwdprd2016',
#  'fwdprd2017',
#  'fwdprd2018',
#  'fwdprd2019',
#  'fwdprd2020',
#  'fwdprd2021',
#  'fwdprd2022',
#  'fwdprd2023',
#  'hvold1996',
#  'hvold1997',
#  'hvold1998',
#  'hvold1999',
#  'hvold2000',
#  'hvold2001',
#  'hvold2002',
#  'hvold2003',
#  'hvold2004',
#  'hvold2005',
#  'hvold2006',
#  'hvold2007',
#  'hvold2008',
#  'hvold2009',
#  'hvold2010',
#  'hvold2011',
#  'hvold2012',
#  'hvold2013',
#  'hvold2014',
#  'hvold2015',
#  'hvold2016',
#  'hvold2017',
#  'hvold2018',
#  'hvold2019',
#  'hvold2020',
#  'hvold2021',
#  'hvold2022',
#  'hvold2023',
#  'idxdvd',
#  'indexd',
#  'opinfd',
#  'opprcd1996',
#  'opprcd1997',
#  'opprcd1998',
#  'opprcd1999',
#  'opprcd2000',
#  'opprcd2001',
#  'opprcd2002',
#  'opprcd2003',
#  'opprcd2004',
#  'opprcd2005',
#  'opprcd2006',
#  'opprcd2007',
#  'opprcd2008',
#  'opprcd2009',
#  'opprcd2010',
#  'opprcd2011',
#  'opprcd2012',
#  'opprcd2013',
#  'opprcd2014',
#  'opprcd2015',
#  'opprcd2016',
#  'opprcd2017',
#  'opprcd2018',
#  'opprcd2019',
#  'opprcd2020',
#  'opprcd2021',
#  'opprcd2022',
#  'opprcd2023',
#  'optionmnames',
#  'opvold',
#  'secnmd',
#  'secprd',
#  'secprd1996',
#  'secprd1997',
#  'secprd1998',
#  'secprd1999',
#  'secprd2000',
#  'secprd2001',
#  'secprd2002',
#  'secprd2003',
#  'secprd2004',
#  'secprd2005',
#  'secprd2006',
#  'secprd2007',
#  'secprd2008',
#  'secprd2009',
#  'secprd2010',
#  'secprd2011',
#  'secprd2012',
#  'secprd2013',
#  'secprd2014',
#  'secprd2015',
#  'secprd2016',
#  'secprd2017',
#  'secprd2018',
#  'secprd2019',
#  'secprd2020',
#  'secprd2021',
#  'secprd2022',
#  'secprd2023',
#  'securd',
#  'securd1',
#  'stdbrte1996',
#  'stdbrte1997',
#  'stdbrte1998',
#  'stdbrte1999',
#  'stdbrte2000',
#  'stdbrte2001',
#  'stdbrte2002',
#  'stdbrte2003',
#  'stdbrte2004',
#  'stdbrte2005',
#  'stdbrte2006',
#  'stdbrte2007',
#  'stdbrte2008',
#  'stdbrte2009',
#  'stdbrte2010',
#  'stdbrte2011',
#  'stdbrte2012',
#  'stdbrte2013',
#  'stdbrte2014',
#  'stdbrte2015',
#  'stdbrte2016',
#  'stdbrte2017',
#  'stdbrte2018',
#  'stdbrte2019',
#  'stdbrte2020',
#  'stdbrte2021',
#  'stdbrte2022',
#  'stdbrte2023',
#  'stdopd1996',
#  'stdopd1997',
#  'stdopd1998',
#  'stdopd1999',
#  'stdopd2000',
#  'stdopd2001',
#  'stdopd2002',
#  'stdopd2003',
#  'stdopd2004',
#  'stdopd2005',
#  'stdopd2006',
#  'stdopd2007',
#  'stdopd2008',
#  'stdopd2009',
#  'stdopd2010',
#  'stdopd2011',
#  'stdopd2012',
#  'stdopd2013',
#  'stdopd2014',
#  'stdopd2015',
#  'stdopd2016',
#  'stdopd2017',
#  'stdopd2018',
#  'stdopd2019',
#  'stdopd2020',
#  'stdopd2021',
#  'stdopd2022',
#  'stdopd2023',
#  'vsurfd1996',
#  'vsurfd1997',
#  'vsurfd1998',
#  'vsurfd1999',
#  'vsurfd2000',
#  'vsurfd2001',
#  'vsurfd2002',
#  'vsurfd2003',
#  'vsurfd2004',
#  'vsurfd2005',
#  'vsurfd2006',
#  'vsurfd2007',
#  'vsurfd2008',
#  'vsurfd2009',
#  'vsurfd2010',
#  'vsurfd2011',
#  'vsurfd2012',
#  'vsurfd2013',
#  'vsurfd2014',
#  'vsurfd2015',
#  'vsurfd2016',
#  'vsurfd2017',
#  'vsurfd2018',
#  'vsurfd2019',
#  'vsurfd2020',
#  'vsurfd2021',
#  'vsurfd2022',
#  'vsurfd2023',
#  'zerocd']

# %% [markdown]
# https://wrds-www.wharton.upenn.edu/search/company-search/code-lookup/?product_id=274&attribute_type_map=
#
# SEC IDs:
# * AAPL: 101594
# * AMZN: 101310
# * GOOG: 203876
# * META: 154402 (also facebook)
# * MSFT: 107525
# * NVDA: 108321
# * TSLA: 143439

# %%
option_data = conn.raw_sql("""
    SELECT 
        date, secid, symbol,
        exdate, cp_flag, strike_price,
        best_bid, best_offer, impl_volatility,
        delta, gamma, vega, theta
    FROM optionm_all.opprcd2023
    WHERE secid IN (101594, 101310, 203876, 154402, 107525, 108321, 143439)
""")

# %%
option_data
# Out:
#               date     secid              symbol      exdate cp_flag  \
# 0       2023-01-03  101310.0  AMZN 230113P107000  2023-01-13       P
# 1       2023-01-03  101310.0  AMZN 230106C100000  2023-01-06       C
# 2       2023-01-03  101310.0  AMZN 230106C101000  2023-01-06       C
# 3       2023-01-03  101310.0  AMZN 230106C102000  2023-01-06       C
# 4       2023-01-03  101310.0  AMZN 230106C103000  2023-01-06       C
# ...            ...       ...                 ...         ...     ...
# 286163  2023-08-31  203876.0   GOOG 251219P75000  2025-12-19       P
# 286164  2023-08-31  203876.0   GOOG 251219P80000  2025-12-19       P
# 286165  2023-08-31  203876.0   GOOG 251219P85000  2025-12-19       P
# 286166  2023-08-31  203876.0   GOOG 251219P90000  2025-12-19       P
# 286167  2023-08-31  203876.0   GOOG 251219P95000  2025-12-19       P
#
#         strike_price  best_bid  best_offer  impl_volatility     delta  \
# 0           107000.0     20.90       21.25              NaN       NaN
# 1           100000.0      0.01        0.02         0.695824  0.008468
# 2           101000.0      0.01        0.02         0.735198  0.008063
# 3           102000.0      0.00        0.02         0.739196  0.005546
# 4           103000.0      0.00        0.02         0.775950  0.005310
# ...              ...       ...         ...              ...       ...
# 286163       75000.0      1.91        3.20         0.369895 -0.061909
# 286164       80000.0      1.89        5.00         0.372652 -0.078801
# 286165       85000.0      2.68        7.00         0.384664 -0.100698
# 286166       90000.0      4.90        6.00         0.370767 -0.115326
# 286167       95000.0      4.00        6.30         0.334854 -0.122666
#
#            gamma       vega     theta
# 0            NaN        NaN       NaN
# 1       0.004262   0.179403 -7.627178
# 2       0.003864   0.172021 -7.717312
# 3       0.002760   0.123522 -5.573145
# 4       0.002530   0.118876 -5.627487
# ...          ...        ...       ...
# 286163  0.001636  25.380010 -1.536992
# 286164  0.001966  30.420810 -1.833900
# 286165  0.002301  36.422150 -2.239982
# 286166  0.002649  39.976550 -2.327705
# 286167  0.003086  41.832890 -2.120587
#
# [3286168 rows x 13 columns]
