# %%
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from datetime import date

# %%
mc = yf.download(tickers= ['SPY','^SP600'],start = date(2020,1,1))['Close']
ew = yf.download(tickers = ['SPXEW','^R2ESC'],start = date(2020,1,1),period ='5y')['Close']
# Out:
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed

# %%
ew
# Out:
# Ticker            SPXEW       ^R2ESC
# Date
# 2020-01-02  4702.990234          NaN
# 2020-01-03  4676.899902          NaN
# 2020-01-06  4683.549805          NaN
# 2020-01-07  4678.370117          NaN
# 2020-01-08  4691.240234          NaN
# ...                 ...          ...
# 2021-09-02  6379.509766          NaN
# 2021-09-03  6358.609863          NaN
# 2021-09-30  6086.189941          NaN
# 2021-10-01  6166.529785          NaN
# 2025-02-12          NaN  4908.745117
#
# [425 rows x 2 columns]

# %%
mc = mc.pct_change().dropna()
ew = ew.pct_change().dropna()


mc = (1 + mc['^SP600'] - mc['SPY']).cumprod()
ew = (1 + ew['^R2ESC'] - ew['SPXEW']).cumprod()
# Out:
# /var/folders/__/wgnmk9j14kl1krf80l2c6bfw0000gn/T/ipykernel_40296/3806892127.py:2: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %%
ew
# Out:
# Series([], dtype: float64)

# %%
fig = go.Figure()


fig.add_trace(
    go.Scatter(
        x = ew.index,
        y = ew,
        name = 'Equal Weight (Small - Large)'
    )
)

fig.add_trace(
    go.Scatter(
        x = mc.index,
        y = mc,
        name = 'Market Cap Weighted (Small - Large) '
    )
)

fig.update_layout(title = 'Small - Large MC vs EW')
fig.update_yaxes(title = 'Cumulative Returns')
fig.show()
